# %% [markdown]
# <a href="https://colab.research.google.com/github/ljl109823-dotcom/MIS2800/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Type this code exactly as shown to install the first library needed for SQLite Magic
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 53.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# Install the SQL extenstion. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been imported
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.db'
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more like a SQL database terminal
# %sql sqlite://AdCampaigns2026.db
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sql/connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 2, in create_engine
#   File "/usr/local/lib/python3.12/dist-packages/sqlalchemy/util/deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sqlalchemy/engine/create.py", line 633, in create_engine
#     (cargs_tup, cparams) = dialect.create_connect_args(u)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sqlalchemy/dialects/sqlite/pysqlite.py", line 566, in create_connect_args
#     raise exc.ArgumentError(
# sqlalchemy.exc.ArgumentError: Invalid SQLite URL: sqlite://AdCampaigns2026.db
# Valid SQLite URL forms are:
#  sqlite:///:memory: (or, sqlite://)
# ...

# %%
#Block 1
# Instructions: There is a typo in the table. Hint: a word is missing.
# %%sql
CREATE TABLE Marketing_Brands (
  brand_id INTEGER PRIMARY KEY,
  brand_name TEXT,
  brand_type TEXT,
  brand_budget INTEGER
) STRICT;
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sql/magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sql/connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
#Block 2

# %%sql
INSERT INTO (brand_id, brand_name, brand_type, brand_budget)
VALUES
  (1, 'Doritos', 'Snacks', 7000000),
  (2, 'AWS', 'Technology', 15000000),
  (3, 'Pepsi', 'Beverages', 2000000),
  (4, 'He_Gets_Us', 'Religious', 1000000),
  (5, 'Dr_Pepper', 'Beverages', 5000000),
  (6, 'IBM', 'Technology', 100000),
  (7, 'Google', 'Technology', 8000000);
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sql/magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sql/connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# from the Marketing_Brands table
# %%sql

SELECT * FROM Marketing_Brands;
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sql/magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sql/connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
$ brand types that had budget over 700000

# %%sql
SELECT * FROM Marketing_Brands
WHERE brand_budget > 700000

# %%
#Block 5

# %%sql
-- Instructions: Fix the code to find the brand types that are Religious
SELECT * FROM Marketing_Brands
WHERE brand_type = 'Religious'

# %%
# brand names that have a budget under 1000000

# %%sql
SELECT * FROM Marketing_Brands
WHERE brand_budget < 100000

# %%
# Colab without having to wrap in Python.

# %%sql
SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000

# %%
# %%sql
# --Instructions: Find the brands where the brand type is
# # Snacks or Beverages. Display only the brand names.
# SELECT * FROM Marketing_Brands
# WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';

# %%
# %%sql
#
# # DESC order. Display only the brand_name and brand_budget.
# SELECT brand_name, brand_budget
# FROM Marketing_Brands
# ORDER BY brand_budget DESC;

# %%
# Using SQLite3 (and all its magic) to create a
# table showing all the columns in ascending order by budget.

# %%sql
SELECT * FROM Marketing_Brands
ORDER BY brand_budget ASC;

# %% [markdown]
# 1. I added the word TABLE because it was missing.

# %% [markdown]
# 2. The word INTO was missing and a comma.
# 3. It was missing a * inbetween.
# 4. Missing a * and a line of code showing where and > 700000
# 5. Same thing as before with a missing * and line showing where.
# 6. Same thing with the missing * and code
# 7. Mising the %%sql
# 8. Missing the From and what categories
# 9. Was missing where to select, from, and how to order
# 10. Was missing everything, the sql%%, SELECT FROM and how to order.
